# %% [markdown]
# **Exploratory data Analysis **process of understanding the data before applying the ml model.
# 1.raw data 2.structured data 3.data preprocessing 4.eda 5.insights,reports and visual graphs

# %%
import pandas as pd
df = pd.read_csv('/raw_data.csv')
print(df)
# Out:
#     Name     Age          Marks       City
# 0   Asha      20             89    Chennai
# 1   Ravi  twenty             75  Bangalore
# 2  Priya      19            NaN    Chennai
# 3  Karan      22             90  Bangalore
# 4  Priya      19            NaN    Chennai
# 5  Meena      21             85  Hyderabad
# 6   John      18  not available     Mumbai

# %%
#view first view rows
df.head()
# Out:
#     Name     Age Marks       City
# 0   Asha      20    89    Chennai
# 1   Ravi  twenty    75  Bangalore
# 2  Priya      19   NaN    Chennai
# 3  Karan      22    90  Bangalore
# 4  Priya      19   NaN    Chennai

# %%
df
# Out:
#     Name     Age          Marks       City
# 0   Asha      20             89    Chennai
# 1   Ravi  twenty             75  Bangalore
# 2  Priya      19            NaN    Chennai
# 3  Karan      22             90  Bangalore
# 4  Priya      19            NaN    Chennai
# 5  Meena      21             85  Hyderabad
# 6   John      18  not available     Mumbai

# %%
#to check columns
df.columns
# Out:
# Index(['Name', 'Age', 'Marks', 'City'], dtype='object')

# %%
#check for missing values
df.isnull().sum()
# Out:
# Name     0
# Age      0
# Marks    2
# City     0
# dtype: int64

# %%
#get basic statistics like min,max,count,freq
df.describe()
# Out:
#          Name Age Marks     City
# count       7   7     5        7
# unique      6   6     5        4
# top     Priya  19    89  Chennai
# freq        2   2     1        3

# %% [markdown]
# # **Structured data**

# %%
#check your dataset is structured
df.head()
# Out:
#     Name     Age Marks       City
# 0   Asha      20    89    Chennai
# 1   Ravi  twenty    75  Bangalore
# 2  Priya      19   NaN    Chennai
# 3  Karan      22    90  Bangalore
# 4  Priya      19   NaN    Chennai

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      object
#  1   Age     7 non-null      object
#  2   Marks   5 non-null      object
#  3   City    7 non-null      object
# dtypes: object(4)
# memory usage: 356.0+ bytes

# %% [markdown]
# # ***Data preprocessing***

# %%
#handling missing values
#check missing values
print(df.isnull().sum())
# Out:
# Name     0
# Age      0
# Marks    2
# City     0
# dtype: int64

# %%
#fill missing values with a specific value
df['Marks']=df['Marks'].fillna(0)
print(df)
# Out:
#     Name     Age          Marks       City
# 0   Asha      20             89    Chennai
# 1   Ravi  twenty             75  Bangalore
# 2  Priya      19              0    Chennai
# 3  Karan      22             90  Bangalore
# 4  Priya      19              0    Chennai
# 5  Meena      21             85  Hyderabad
# 6   John      18  not available     Mumbai

# %%
df['Marks']=pd.to_numeric(df['Marks'],errors='coerce')
print(df)
# Out:
#     Name     Age  Marks       City
# 0   Asha      20   89.0    Chennai
# 1   Ravi  twenty   75.0  Bangalore
# 2  Priya      19    0.0    Chennai
# 3  Karan      22   90.0  Bangalore
# 4  Priya      19    0.0    Chennai
# 5  Meena      21   85.0  Hyderabad
# 6   John      18    NaN     Mumbai

# %%
#replace only the word twenty with number 20
df['Age']=df['Age'].replace('twenty',20)
print(df)
df['Marks']=df['Marks'].fillna(0)
print(df)
# Out:
#     Name  Age  Marks       City
# 0   Asha   20   89.0    Chennai
# 1   Ravi   20   75.0  Bangalore
# 2  Priya   19    0.0    Chennai
# 3  Karan   22   90.0  Bangalore
# 4  Priya   19    0.0    Chennai
# 5  Meena   21   85.0  Hyderabad
# 6   John   18   56.5     Mumbai
#     Name  Age  Marks       City
# 0   Asha   20   89.0    Chennai
# 1   Ravi   20   75.0  Bangalore
# 2  Priya   19    0.0    Chennai
# 3  Karan   22   90.0  Bangalore
# 4  Priya   19    0.0    Chennai
# 5  Meena   21   85.0  Hyderabad
# 6   John   18   56.5     Mumbai
